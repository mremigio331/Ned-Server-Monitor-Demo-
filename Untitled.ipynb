# %%
import streamlit as st
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import altair as alt

from Additional_py_Files import db_connect as db

# %%
auth_logs = db.auth_logs_to_df()

# %%
auth_logs
# Out:
#                   Date_Time        Date      Time        Source_IP  \
# 0       2021/11/28 23:49:02  2021/11/28  23:49:02    23.82.193.161
# 1       2021/11/28 23:48:58  2021/11/28  23:48:58    23.82.193.161
# 2       2021/11/28 23:48:55  2021/11/28  23:48:55    23.82.193.161
# 3       2021/11/28 23:48:53  2021/11/28  23:48:53    23.82.193.161
# 4       2021/11/28 23:48:40  2021/11/28  23:48:40     64.225.78.56
# ...                     ...         ...       ...              ...
# 169810  2022/01/02 00:04:02  2022/01/02  00:04:02     43.153.29.11
# 169811  2022/01/02 00:02:44  2022/01/02  00:02:44     43.153.17.40
# 169812  2022/01/02 00:02:39  2022/01/02  00:02:39     43.153.29.11
# 169813  2022/01/02 00:01:21  2022/01/02  00:01:21     43.153.29.11
# 169814  2022/01/02 00:01:04  2022/01/02  00:01:04  193.169.254.138
#
#             Access      Box    User      By_Way       City        Country  \
# 0       Successful  Liberty    root  Public_Key   Manassas  United States
# ...

# %%
box_list =  auth_logs['Box'].tolist()

new_box_list = []
for x in box_list:
    if x in new_box_list:
        pass
    else:
        new_box_list.append(x)
        
new_box_list
# Out:
# ['Liberty', 'Ellis', 'Itza', 'Alban', 'Volvo', 'Ikea', 'Mitsubishi', 'Subaru']

# %%
ips = auth_logs['Source_IP'].tolist()
new_ip_list = []
for x in ips:
    if x in new_ip_list:
        pass
    else:
        new_ip_list.append(x)
        
#new_ip_list

# %%
# Out:
#                 Time
# Source_IP
# 1.214.81.50        1
# 1.224.249.138      1
# 1.65.130.113       2
# 101.166.192.3      2
# 101.33.243.112  6659
# ...              ...
# 96.255.93.142    315
# 96.8.2.65          1
# 96.86.194.5       11
# 97.126.99.1        2
# 98.199.124.73      1
#
# [915 rows x 1 columns]
