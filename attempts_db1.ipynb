# %%
import streamlit as st
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import altair as alt

from Additional_py_Files import db_connect as db

# %%
auth_logs = db.auth_logs_to_df()
failed_logs = auth_logs.loc[auth_logs['Access'] == 'Failed']

# %%
failed_logs
# Out:
#                   Date_Time        Date      Time        Source_IP  Access  \
# 4       2021/11/28 23:48:40  2021/11/28  23:48:40     64.225.78.56  Failed
# 8       2021/11/28 23:47:42  2021/11/28  23:47:42     64.225.78.56  Failed
# 10      2021/11/28 23:46:44  2021/11/28  23:46:44     64.225.78.56  Failed
# 11      2021/11/28 23:45:46  2021/11/28  23:45:46     64.225.78.56  Failed
# 12      2021/11/28 23:44:49  2021/11/28  23:44:49     64.225.78.56  Failed
# ...                     ...         ...       ...              ...     ...
# 169810  2022/01/02 00:04:02  2022/01/02  00:04:02     43.153.29.11  Failed
# 169811  2022/01/02 00:02:44  2022/01/02  00:02:44     43.153.17.40  Failed
# 169812  2022/01/02 00:02:39  2022/01/02  00:02:39     43.153.29.11  Failed
# 169813  2022/01/02 00:01:21  2022/01/02  00:01:21     43.153.29.11  Failed
# 169814  2022/01/02 00:01:04  2022/01/02  00:01:04  193.169.254.138  Failed
#
# ...

# %%
box_ipfail_list =  failed_logs['Box'].tolist()

# %%
new_box_ipfail_list = []
for x in box_ipfail_list:
    if x in new_box_ipfail_list:
        pass
    else:
        new_box_ipfail_list.append(x)
        
new_box_ipfail_list
# Out:
# ['Itza', 'Ellis', 'Alban', 'Liberty', 'Ikea', 'Volvo', 'Subaru', 'Mitsubishi']

# %%
full_ip_fail = []
for x in new_box_ipfail_list:
    df = 
    ip_fail = failed_logs.groupby('Source_IP')['Time'].nunique()
    ip_fail_df = ip_fail.to_frame()
    ip_fail_df.rename({'Time':x}, axis=1, inplace=True)
    ip_fail_df = ip_fail_df.reset_index()
    ip_fail_df = ip_fail_df.sort_values(by=x, ascending=False)
    ip_fail_list = ip_fail_df.index.tolist()
    ip_list_count = len(ip_fail_list)
    ip_fail_df = ip_fail_df.sort_values(by=x, ascending=False)
    ip_fail_df[x] = ip_fail_df[x].fillna(0)
    
    full_ip_fail.append(ip_fail_df)

frame = pd.concat(full_ip_fail, axis=0, ignore_index=True)
frame
# Out:
#            Source_IP     Itza  Ellis  Alban  Liberty  Ikea  Volvo  Subaru  \
# 0       61.177.173.7  18747.0    NaN    NaN      NaN   NaN    NaN     NaN
# 1     61.177.172.158  13973.0    NaN    NaN      NaN   NaN    NaN     NaN
# 2      196.1.236.246  11675.0    NaN    NaN      NaN   NaN    NaN     NaN
# 3       218.92.0.211  11458.0    NaN    NaN      NaN   NaN    NaN     NaN
# 4       216.238.78.6  11455.0    NaN    NaN      NaN   NaN    NaN     NaN
# ...              ...      ...    ...    ...      ...   ...    ...     ...
# 7147   121.201.34.21      NaN    NaN    NaN      NaN   NaN    NaN     NaN
# 7148   121.81.65.146      NaN    NaN    NaN      NaN   NaN    NaN     NaN
# 7149    124.43.64.13      NaN    NaN    NaN      NaN   NaN    NaN     NaN
# 7150   49.158.25.166      NaN    NaN    NaN      NaN   NaN    NaN     NaN
# 7151   98.199.124.73      NaN    NaN    NaN      NaN   NaN    NaN     NaN
#
#       Mitsubishi
# 0            NaN
# 1            NaN
# 2            NaN
# ...

# %%
frame['Boxes Hit'] = 8 - frame.isnull().sum(axis=1)

# %%
frame = frame.sort_values(by='Boxes Hit', ascending=False)
frame
# Out:
#             Source_IP     Itza  Ellis  Alban  Liberty  Ikea  Volvo  Subaru  \
# 0        61.177.173.7  18747.0    NaN    NaN      NaN   NaN    NaN     NaN
# 4764   34.159.250.194      NaN    NaN    NaN      NaN   NaN    7.0     NaN
# 4775  185.220.102.252      NaN    NaN    NaN      NaN   NaN    6.0     NaN
# 4774  185.213.155.169      NaN    NaN    NaN      NaN   NaN    6.0     NaN
# 4773  116.105.172.122      NaN    NaN    NaN      NaN   NaN    6.0     NaN
# ...               ...      ...    ...    ...      ...   ...    ...     ...
# 2380    112.206.3.223      NaN    NaN    1.0      NaN   NaN    NaN     NaN
# 2379   112.195.76.249      NaN    NaN    1.0      NaN   NaN    NaN     NaN
# 2378  113.102.204.254      NaN    NaN    1.0      NaN   NaN    NaN     NaN
# 2377   178.201.83.134      NaN    NaN    1.0      NaN   NaN    NaN     NaN
# 7151    98.199.124.73      NaN    NaN    NaN      NaN   NaN    NaN     NaN
#
#       Mitsubishi  Boxes Hit
# 0            NaN          1
# ...

# %%
ip_fail = failed_logs.groupby('Source_IP')['Time'].nunique()
ip_fail_df = ip_fail.to_frame()
ip_fail_df.rename({'Time':'Count'}, axis=1, inplace=True)
ip_fail_df = ip_fail_df.reset_index()
ip_fail_df = ip_fail_df.sort_values(by='Count', ascending=False)
ip_fail_list = ip_fail_df.index.tolist()
ip_list_count = len(ip_fail_list)

# %%
ip_fail_df = ip_fail_df.sort_values(by='Count', ascending=False)

# %%
ip_fail_df
# Out:
#           Source_IP  Count
# 715    61.177.173.7  18747
# 711  61.177.172.158  13973
# 452   196.1.236.246  11675
# 516    218.92.0.211  11458
# 510    216.238.78.6  11455
# ..              ...    ...
# 228   121.201.34.21      1
# 231   121.81.65.146      1
# 241    124.43.64.13      1
# 674   49.158.25.166      1
# 893   98.199.124.73      1
#
# [894 rows x 2 columns]

# %%
pass_logs = auth_logs.loc[auth_logs['Access'] == 'Successful']

# %%
pass_logs
# Out:
#                   Date_Time        Date      Time       Source_IP      Access  \
# 0       2021/11/28 23:49:02  2021/11/28  23:49:02   23.82.193.161  Successful
# 1       2021/11/28 23:48:58  2021/11/28  23:48:58   23.82.193.161  Successful
# 2       2021/11/28 23:48:55  2021/11/28  23:48:55   23.82.193.161  Successful
# 3       2021/11/28 23:48:53  2021/11/28  23:48:53   23.82.193.161  Successful
# 5       2021/11/28 23:48:37  2021/11/28  23:48:37   23.82.193.161  Successful
# ...                     ...         ...       ...             ...         ...
# 167511  2022/01/02 16:47:54  2022/01/02  16:47:54  172.58.159.176  Successful
# 167512  2022/01/02 16:47:51  2022/01/02  16:47:51  172.58.159.176  Successful
# 167513  2022/01/02 16:47:47  2022/01/02  16:47:47  172.58.159.176  Successful
# 167514  2022/01/02 16:47:43  2022/01/02  16:47:43  172.58.159.176  Successful
# 167515  2022/01/02 16:47:40  2022/01/02  16:47:40  172.58.159.176  Successful
#
# ...

# %%
box_ippass_list =  pass_logs['Box'].tolist()

# %%
new_box_ippass_list = []
for x in box_ippass_list:
    if x in new_box_ippass_list:
        pass
    else:
        new_box_ippass_list.append(x)
        
new_box_ippass_list
# Out:
# ['Liberty', 'Ellis', 'Itza', 'Alban', 'Volvo', 'Ikea', 'Mitsubishi', 'Subaru']

# %%
full_ip_pass = []
for x in new_box_ippass_list:
    ip_pass = pass_logs.groupby('Source_IP')['Time'].nunique()
    ip_pass_df = ip_pass.to_frame()
    ip_pass_df.rename({'Time':x}, axis=1, inplace=True)
    ip_pass_df = ip_pass_df.reset_index()
    ip_pass_df = ip_pass_df.sort_values(by=x, ascending=False)
    ip_pass_list = ip_pass_df.index.tolist()
    ip_pass_count = len(ip_pass_list)
    ip_pass_df = ip_pass_df.sort_values(by=x, ascending=False)
    ip_pass_df[x] = ip_pass_df[x].fillna(0)
    
    full_ip_pass.append(ip_pass_df)

pass_frame = pd.concat(full_ip_pass, axis=0, ignore_index=True)
pass_frame
# Out:
#            Source_IP  Liberty  Ellis  Itza  Alban  Volvo  Ikea  Mitsubishi  \
# 0    192.173.171.215    714.0    NaN   NaN    NaN    NaN   NaN         NaN
# 1      67.161.98.179    340.0    NaN   NaN    NaN    NaN   NaN         NaN
# 2       94.140.8.221    116.0    NaN   NaN    NaN    NaN   NaN         NaN
# 3      176.113.72.94    114.0    NaN   NaN    NaN    NaN   NaN         NaN
# 4    185.187.243.214     87.0    NaN   NaN    NaN    NaN   NaN         NaN
# ..               ...      ...    ...   ...    ...    ...   ...         ...
# 203    176.113.72.93      NaN    NaN   NaN    NaN    NaN   NaN         NaN
# 204   172.58.158.177      NaN    NaN   NaN    NaN    NaN   NaN         NaN
# 205     94.140.8.153      NaN    NaN   NaN    NaN    NaN   NaN         NaN
# 206   50.212.209.222      NaN    NaN   NaN    NaN    NaN   NaN         NaN
# 207    172.58.41.114      NaN    NaN   NaN    NaN    NaN   NaN         NaN
#
#      Subaru
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# ...

# %%
pass_frame['Boxes Hit'] = 8 - pass_frame.isnull().sum(axis=1)
pass_frame = pass_frame.sort_values(by='Boxes Hit', ascending=False)
pass_frame
# Out:
#            Source_IP  Liberty  Ellis  Itza  Alban  Volvo   Ikea  Mitsubishi  \
# 0    192.173.171.215    714.0    NaN   NaN    NaN    NaN    NaN         NaN
# 1      67.161.98.179    340.0    NaN   NaN    NaN    NaN    NaN         NaN
# 132     94.140.8.221      NaN    NaN   NaN    NaN    NaN  116.0         NaN
# 133    176.113.72.94      NaN    NaN   NaN    NaN    NaN  114.0         NaN
# 134  185.187.243.214      NaN    NaN   NaN    NaN    NaN   87.0         NaN
# ..               ...      ...    ...   ...    ...    ...    ...         ...
# 72    172.58.159.176      NaN    NaN   8.0    NaN    NaN    NaN         NaN
# 73     176.113.72.93      NaN    NaN   8.0    NaN    NaN    NaN         NaN
# 74    172.58.158.177      NaN    NaN   8.0    NaN    NaN    NaN         NaN
# 75      94.140.8.153      NaN    NaN   7.0    NaN    NaN    NaN         NaN
# 207    172.58.41.114      NaN    NaN   NaN    NaN    NaN    NaN         NaN
#
#      Subaru  Boxes Hit
# 0       NaN          1
# ...
